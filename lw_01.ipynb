# %% [markdown]
# <a href="https://colab.research.google.com/github/knyazevaanna16-arch/algorithmization_tsib_251_13/blob/main/lw_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Лабораторная работа 1
# Задание 12: Симуляция очереди печати принтера (добавление задач и "печать").
#
# Выполнил: Князева А. П.
# Группа: ЦИБ-251

printer_queue = []

print("Симуляция очереди печати принтера")

while True:
    print("\nОчередь печати:", printer_queue)
    print("1 - Добавить задачу")
    print("2 - Печать")
    print("3 - Выход")

    choice = input("Выберите действие (1-3): ")

    if choice == "1":
        task = input("Введите имя документа: ")
        printer_queue.append(task)
        print(f"Добавлено: {task}")

    elif choice == "2":
        if printer_queue:
            task = printer_queue.pop(0)
            print(f"Печатается: {task}")
        else:
            print("Нет задач в очереди")

    elif choice == "3":
        print("Программа завершена. До свидания!")
        break
# Out:
# Симуляция очереди печати принтера
#
# Очередь печати: []
# 1 - Добавить задачу
# 2 - Печать
# 3 - Выход
# Выберите действие (1-3): 1
# Введите имя документа: расписание
# Добавлено: расписание
#
# Очередь печати: ['расписание']
# 1 - Добавить задачу
# 2 - Печать
# 3 - Выход
# Выберите действие (1-3): 1
# Введите имя документа: курсовая
# Добавлено: курсовая
#
# Очередь печати: ['расписание', 'курсовая']
# 1 - Добавить задачу
# 2 - Печать
# 3 - Выход
# Выберите действие (1-3): 1
# Введите имя документа: практика
# Добавлено: практика
#
# Очередь печати: ['расписание', 'курсовая', 'практика']
# 1 - Добавить задачу
# 2 - Печать
# 3 - Выход
# Выберите действие (1-3): 1
# Введите имя документа: домашка
# Добавлено: домашка
#
# Очередь печати: ['расписание', 'курсовая', 'практика', 'домашка']
# 1 - Добавить задачу
# 2 - Печать
# 3 - Выход
# Выберите действие (1-3): 2
# Печатается: расписание
#
# Очередь печати: ['курсовая', 'практика', 'домашка']
# 1 - Добавить задачу
# 2 - Печать
# ...

# %% [markdown]
# **Блок-схема**

# %% [markdown]
# ![lw_01.png](data:image/png;base64,...)
